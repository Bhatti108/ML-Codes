# %%
print("Anas")
# Out:
# Anas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/MELBOURNE_HOUSE_PRICES_LESS.csv')
df.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname  Propertycount  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 3  1/04/2017      3040   Western Metropolitan           1543       7.5
# 4  1/04/2017      3042   Western Metropolitan           3464      10.4
#
#                   CouncilArea
# 0          Yarra City Council
# 1          Yarra City Council
# ...

# %%
df.nunique()
# Out:
# Suburb             380
# Address          57754
# Rooms               14
# Type                 3
# Price             3417
# Method               9
# SellerG            476
# Date               112
# Postcode           225
# Regionname           8
# Propertycount      368
# Distance           180
# CouncilArea         34
# dtype: int64

# %%
df.shape
# Out:
# (63023, 13)

# %%
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG',
               'Distance', 'Bedroom2', 'Bathroom', 'Car',
               'Landsize', 'BuildingArea', 'Price']

df = df.loc[:, [col for col in cols_to_use if col in df.columns]]
print(df.head())
# Out:
#          Suburb  Rooms Type Method   SellerG  Distance      Price
# 0    Abbotsford      3    h      S    Jellis       3.0  1490000.0
# 1    Abbotsford      3    h      S  Marshall       3.0  1220000.0
# 2    Abbotsford      3    h      S    Nelson       3.0  1420000.0
# 3    Aberfeldie      3    h      S     Barry       7.5  1515000.0
# 4  Airport West      2    h      S    Nelson      10.4   670000.0

# %%
df.shape
# Out:
# (63023, 7)

# %%
df.isna().sum()
# Out:
# Suburb          0
# Rooms           0
# Type            0
# Method          0
# SellerG         0
# Distance        0
# Price       14590
# dtype: int64

# %%
df=pd.get_dummies(df,drop_first=True)
df.head()
# Out:
#    Rooms  Distance      Price  Suburb_Aberfeldie  Suburb_Airport West  \
# 0      3       3.0  1490000.0              False                False
# 1      3       3.0  1220000.0              False                False
# 2      3       3.0  1420000.0              False                False
# 3      3       7.5  1515000.0               True                False
# 4      2      10.4   670000.0              False                 True
#
#    Suburb_Albanvale  Suburb_Albert Park  Suburb_Albion  Suburb_Alphington  \
# 0             False               False          False              False
# 1             False               False          False              False
# 2             False               False          False              False
# 3             False               False          False              False
# 4             False               False          False              False
#
#    Suburb_Altona  ...  SellerG_hockingstuart/Purplebricks  \
# ...

# %%
X=df.drop('Price',axis=1)
y=df['Price']

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
if y_train.isnull().any():
    print("NaN values found in y_train. Handling them...")

    y_train = y_train.dropna()
    X_train = X_train.loc[y_train.index]

# %%
# Train the model
reg = LinearRegression().fit(X_train, y_train)

# %%
# Ensure that X_test and y_test do not contain NaN values
if X_test.isnull().any().any() or y_test.isnull().any():
    print("NaN values found in X_test or y_test. Handling them...")

    # Drop rows with NaNs in X_test or y_test
    valid_indices = X_test.dropna().index.intersection(y_test.dropna().index)
    X_test = X_test.loc[valid_indices]
    y_test = y_test.loc[valid_indices]

# Calculate the model's score
score = reg.score(X_test, y_test)
print("Model Score:", score)
# Out:
# NaN values found in X_test or y_test. Handling them...
# Model Score: 0.648969775666304

# %%
reg.score(X_train,y_train)
# Out:
# 0.6658330373412857

# %%
from sklearn import linear_model
lasso_reg=linear_model.Lasso(alpha=50,max_iter=100,tol=0.1)
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(X_test,y_test)
# Out:
# 0.6485652316339079

# %%
lasso_reg.score(X_train,y_train)
# Out:
# 0.6602519065721305

# %%
from sklearn.linear_model import Ridge
ridge_reg=Ridge(alpha=50,max_iter=100,tol=0.1)
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(X_test,y_test)
# Out:
# 0.6226660632307429

# %%
ridge_reg.score(X_train,y_train)
# Out:
# 0.635706672699347
